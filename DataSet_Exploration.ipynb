# %% [markdown]
# # First Draft DataScope Exploration of CTA Data for a Business Looking to Locate in Chicago

# %%
import pandas as pd
import numpy as np
import mplleaflet
import matplotlib.pyplot as plt

# %%
# Import the Turnstile Data
turnstile_data = pd.read_csv('CTA_-_Ridership_-__L__Station_Entries_-_Daily_Totals.csv')
# import the Station Data
station_data = pd.read_csv('CTA_-_System_Information_-_List_of__L__Stops.csv')

# %%
turnstile_data.columns
# Out:
# Index([u'station_id', u'stationname', u'date', u'daytype', u'rides'], dtype='object')

# %%
station_data.columns
# Out:
# Index([u'STOP_ID', u'DIRECTION_ID', u'STOP_NAME', u'STATION_NAME',
#        u'STATION_DESCRIPTIVE_NAME', u'MAP_ID', u'ADA', u'RED', u'BLUE', u'G',
#        u'BRN', u'P', u'Pexp', u'Y', u'Pnk', u'O', u'Location'],
#       dtype='object')

# %%
# We see that station ID is the same as MAP_ID
print "Number of Stop IDS", len(station_data['STOP_ID'].unique()) 
print "Number of Stations ID in Turnstile Data Set", len(turnstile_data['station_id'].unique())
print "Number of MAP ID's in Station Data", len(station_data['MAP_ID'].unique())

not_found = []
# BUT!!! These two Station ID are not in Map ID
for tid in turnstile_data['station_id'].unique():
    if not(tid in station_data['MAP_ID'].unique()):
        print "Value in Turnstile data Not found in Station Data", tid
        not_found.append(tid)
# 40500 is Washington/State  Maybe same as Library?
# 45180 is Homan and has almost all empty Values for number of rides 
#turnstile_data[turnstile_data['station_id'] == 40500]
#turnstile_data[turnstile_data['station_id'] == 41580]

# EXCLUDING THESE TWO VALUES IN EVALUATION OF DATA
# Out:
# Number of Stop IDS 300
# Number of Stations ID in Turnstile Data Set 146
# Number of MAP ID's in Station Data 144
# Value in Turnstile data Not found in Station Data 40500
# Value in Turnstile data Not found in Station Data 41580

# %%
pd.set_option('display.max_rows', 20)
#turnstile_data['station_id'].value_counts()

# %%
# Let's take a look at the Station Data
station_data
# Out:
#      STOP_ID DIRECTION_ID                                     STOP_NAME  \
# 0      30162            W                      18th (54th/Cermak-bound)
# 1      30161            E                             18th (Loop-bound)
# 2      30022            N                      35th/Archer (Loop-bound)
# 3      30023            S                    35th/Archer (Midway-bound)
# 4      30214            S               35-Bronzeville-IIT (63rd-bound)
# 5      30213            N             35-Bronzeville-IIT (Harlem-bound)
# 6      30246            S                             43rd (63rd-bound)
# 7      30245            N                           43rd (Harlem-bound)
# 8      30025            S                             51st (63rd-bound)
# 9      30024            N                           51st (Harlem-bound)
# ..       ...          ...                                           ...
# 290    30223            N                       Garfield (Howard-bound)
# 291    30190            W  Harlem (Forest Pk Branch) (Terminal arrival)
# 292    30165            E                     H.W. Library (Outer Loop)
# 293    30130            S     Western (O'Hare Branch) (Forest Pk-bound)
# 294    30289            N                           Lake (Howard-bound)
# 295    30270            S                        Roosevelt (95th-bound)
# 296    30171            N                     O'Hare (Terminal Arrival)
# 297    30042            E     Western (Forest Pk Branch) (O'Hare-bound)
# 298    30043            W  Western (Forest Pk Branch) (Forest Pk-bound)
# 299    30129            N        Western (O'Hare Branch) (O'Hare-bound)
#
#                                   STATION_NAME  \
# 0                                         18th
# 1                                         18th
# 2                                  35th/Archer
# 3                                  35th/Archer
# 4                         35th-Bronzeville-IIT
# 5                         35th-Bronzeville-IIT
# 6                                         43rd
# 7                                         43rd
# 8                                         51st
# 9                                         51st
# ..                                         ...
# 290                                   Garfield
# 291                                     Harlem
# 292  Harold Washington Library-State/Van Buren
# 293                                    Western
# 294                                       Lake
# 295                                  Roosevelt
# 296                                     O'Hare
# 297                                    Western
# 298                                    Western
# 299                                    Western
#
#                               STATION_DESCRIPTIVE_NAME  MAP_ID    ADA    RED  \
# 0                                     18th (Pink Line)   40830   True  False
# 1                                     18th (Pink Line)   40830   True  False
# 2                            35th/Archer (Orange Line)   40120   True  False
# 3                            35th/Archer (Orange Line)   40120   True  False
# 4                    35th-Bronzeville-IIT (Green Line)   41120   True  False
# 5                    35th-Bronzeville-IIT (Green Line)   41120   True  False
# 6                                    43rd (Green Line)   41270   True  False
# 7                                    43rd (Green Line)   41270   True  False
# 8                                    51st (Green Line)   40130   True  False
# 9                                    51st (Green Line)   40130   True  False
# ..                                                 ...     ...    ...    ...
# 290                                Garfield (Red Line)   41170   True   True
# 291            Harlem (Blue Line - Forest Park Branch)   40980  False  False
# 292  Harold Washington Library-State/Van Buren (Bro...   40850   True  False
# 293                Western (Blue Line - O'Hare Branch)   40670   True  False
# 294                                    Lake (Red Line)   41660   True   True
# 295              Roosevelt (Red, Orange & Green Lines)   41400   True   True
# 296                                 O'Hare (Blue Line)   40890   True  False
# 297           Western (Blue Line - Forest Park Branch)   40220  False  False
# 298           Western (Blue Line - Forest Park Branch)   40220  False  False
# 299                Western (Blue Line - O'Hare Branch)   40670   True  False
#
#       BLUE      G    BRN      P   Pexp      Y    Pnk      O  \
# 0    False  False  False  False  False  False   True  False
# 1    False  False  False  False  False  False   True  False
# 2    False  False  False  False  False  False  False   True
# 3    False  False  False  False  False  False  False   True
# 4    False   True  False  False  False  False  False  False
# 5    False   True  False  False  False  False  False  False
# 6    False   True  False  False  False  False  False  False
# 7    False   True  False  False  False  False  False  False
# 8    False   True  False  False  False  False  False  False
# 9    False   True  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...
# 290  False  False  False  False  False  False  False  False
# 291   True  False  False  False  False  False  False  False
# 292  False  False   True  False  False  False  False  False
# 293   True  False  False  False  False  False  False  False
# 294  False  False  False  False  False  False  False  False
# 295  False  False  False  False  False  False  False  False
# 296   True  False  False  False  False  False  False  False
# 297   True  False  False  False  False  False  False  False
# 298   True  False  False  False  False  False  False  False
# 299   True  False  False  False  False  False  False  False
#
#                         Location
# 0        (41.857908, -87.669147)
# 1        (41.857908, -87.669147)
# 2        (41.829353, -87.680622)
# 3        (41.829353, -87.680622)
# 4        (41.831677, -87.625826)
# 5        (41.831677, -87.625826)
# 6        (41.816462, -87.619021)
# 7        (41.816462, -87.619021)
# 8         (41.80209, -87.618487)
# 9         (41.80209, -87.618487)
# ..                           ...
# 290       (41.79542, -87.631157)
# 291       (41.87349, -87.806961)
# 292      (41.876862, -87.628196)
# 293      (41.916157, -87.687364)
# 294      (41.884809, -87.627813)
# 295      (41.867368, -87.627402)
# 296  (41.97766526, -87.90422307)
# 297      (41.875478, -87.688436)
# 298      (41.875478, -87.688436)
# 299      (41.916157, -87.687364)
#
# [300 rows x 17 columns]

# %%
# Remove STOP_ID, Directon_ID, and the Stop Name
station_data_cleaned = station_data.drop(station_data.columns[0:3], axis = 1)
station_data_cleaned.drop_duplicates(inplace=True)
station_data_cleaned
# Out:
#                                   STATION_NAME  \
# 0                                         18th
# 2                                  35th/Archer
# 4                         35th-Bronzeville-IIT
# 6                                         43rd
# 8                                         51st
# 10                                 54th/Cermak
# 12                                        69th
# 14                                        79th
# 16                               95th/Dan Ryan
# 17                               95th/Ran Ryan
# ..                                         ...
# 277                                       47th
# 280                                 California
# 281                                 California
# 282                                    Chicago
# 283                                    Chicago
# 285                                    Chicago
# 288                                       63rd
# 292  Harold Washington Library-State/Van Buren
# 293                                    Western
# 297                                    Western
#
#                               STATION_DESCRIPTIVE_NAME  MAP_ID    ADA    RED  \
# 0                                     18th (Pink Line)   40830   True  False
# 2                            35th/Archer (Orange Line)   40120   True  False
# 4                    35th-Bronzeville-IIT (Green Line)   41120   True  False
# 6                                    43rd (Green Line)   41270   True  False
# 8                                    51st (Green Line)   40130   True  False
# 10                             54th/Cermak (Pink Line)   40580   True  False
# 12                                     69th (Red Line)   40990   True   True
# 14                                     79th (Red Line)   40240   True   True
# 16                            95th/Dan Ryan (Red Line)   40450   True   True
# 17                            95th/Ran Ryan (Red Line)   40450   True   True
# ..                                                 ...     ...    ...    ...
# 277                                    47th (Red Line)   41230   True   True
# 280                             California (Blue Line)   40570  False  False
# 281                            California  (Blue Line)   40570  False  False
# 282                                Chicago (Blue Line)   41410  False  False
# 283                     Chicago (Brown & Purple Lines)   40710   True  False
# 285                                 Chicago (Red Line)   41450   True   True
# 288                                    63rd (Red Line)   40910   True   True
# 292  Harold Washington Library-State/Van Buren (Bro...   40850   True  False
# 293                Western (Blue Line - O'Hare Branch)   40670   True  False
# 297           Western (Blue Line - Forest Park Branch)   40220  False  False
#
#       BLUE      G    BRN      P   Pexp      Y    Pnk      O  \
# 0    False  False  False  False  False  False   True  False
# 2    False  False  False  False  False  False  False   True
# 4    False   True  False  False  False  False  False  False
# 6    False   True  False  False  False  False  False  False
# 8    False   True  False  False  False  False  False  False
# 10   False  False  False  False  False  False   True  False
# 12   False  False  False  False  False  False  False  False
# 14   False  False  False  False  False  False  False  False
# 16   False  False  False  False  False  False  False  False
# 17   False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...
# 277  False  False  False  False  False  False  False  False
# 280   True  False  False  False  False  False  False  False
# 281   True  False  False  False  False  False  False  False
# 282   True  False  False  False  False  False  False  False
# 283  False  False   True  False   True  False  False  False
# 285  False  False  False  False  False  False  False  False
# 288  False  False  False  False  False  False  False  False
# 292  False  False   True  False  False  False  False  False
# 293   True  False  False  False  False  False  False  False
# 297   True  False  False  False  False  False  False  False
#
#                         Location
# 0        (41.857908, -87.669147)
# 2        (41.829353, -87.680622)
# 4        (41.831677, -87.625826)
# 6        (41.816462, -87.619021)
# 8         (41.80209, -87.618487)
# 10   (41.85177331, -87.75669201)
# 12       (41.768367, -87.625724)
# 14       (41.750419, -87.625112)
# 16       (41.722377, -87.624342)
# 17       (41.722377, -87.624342)
# ..                           ...
# 277       (41.810318, -87.63094)
# 280       (41.921939, -87.69689)
# 281       (41.921939, -87.69689)
# 282      (41.896075, -87.655214)
# 283       (41.89681, -87.635924)
# 285      (41.896671, -87.628176)
# 288      (41.780536, -87.630952)
# 292      (41.876862, -87.628196)
# 293      (41.916157, -87.687364)
# 297      (41.875478, -87.688436)
#
# [162 rows x 14 columns]

# %%
# Logically Combine the Different Color Line Stops at Each Station 
final_station_data = station_data_cleaned.groupby("MAP_ID").first()
logically_combined = station_data_cleaned.groupby("MAP_ID").any()[['ADA', 'RED', 'BLUE', 'G','BRN','P', 'Pexp','Y', 'Pnk', 'O']]
final_station_data[['ADA', 'RED', 'BLUE', 'G','BRN','P', 'Pexp','Y', 'Pnk', 'O']] = logically_combined
final_station_data
# Out:
#                   STATION_NAME  \
# MAP_ID
# 40010                   Austin
# 40020              Harlem/Lake
# 40030                  Pulaski
# 40040             Quincy/Wells
# 40050                    Davis
# 40060                  Belmont
# 40070                  Jackson
# 40080                 Sheridan
# 40090                    Damen
# 40100                    Morse
# ...                        ...
# 41450                  Chicago
# 41460              Irving Park
# 41480                  Western
# 41490                 Harrison
# 41500                 Montrose
# 41510                   Morgan
# 41660                     Lake
# 41670             Conservatory
# 41680            Oakton-Skokie
# 41690   Cermak-McCormick Place
#
#                                  STATION_DESCRIPTIVE_NAME    ADA    RED  \
# MAP_ID
# 40010                                  Austin (Blue Line)  False  False
# 40020                            Harlem/Lake (Green Line)   True  False
# 40030                                Pulaski (Green Line)   True  False
# 40040   Quincy/Wells (Brown, Orange, Purple & Pink Lines)  False  False
# 40050                                 Davis (Purple Line)   True  False
# 40060                                 Belmont (Blue Line)  False  False
# 40070                                 Jackson (Blue Line)   True  False
# 40080                                 Sheridan (Red Line)  False   True
# 40090                                  Damen (Brown Line)   True  False
# 40100                                    Morse (Red Line)  False   True
# ...                                                   ...    ...    ...
# 41450                                  Chicago (Red Line)   True   True
# 41460                            Irving Park (Brown Line)   True  False
# 41480                                Western (Brown Line)   True  False
# 41490                                 Harrison (Red Line)  False   True
# 41500                               Montrose (Brown Line)   True  False
# 41510                         Morgan (Green & Pink Lines)   True  False
# 41660                                     Lake (Red Line)   True   True
# 41670                           Conservatory (Green Line)   True  False
# 41680                         Oakton-Skokie (Yellow Line)   True  False
# 41690                 Cermak-McCormick Place (Green Line)   True  False
#
#          BLUE      G    BRN      P   Pexp      Y    Pnk      O  \
# MAP_ID
# 40010    True  False  False  False  False  False  False  False
# 40020   False   True  False  False  False  False  False  False
# 40030   False   True  False  False  False  False  False  False
# 40040   False  False   True  False   True  False   True   True
# 40050   False  False  False   True   True  False  False  False
# 40060    True  False  False  False  False  False  False  False
# 40070    True  False  False  False  False  False  False  False
# 40080   False  False  False  False  False  False  False  False
# 40090   False  False   True  False  False  False  False  False
# 40100   False  False  False  False  False  False  False  False
# ...       ...    ...    ...    ...    ...    ...    ...    ...
# 41450   False  False  False  False  False  False  False  False
# 41460   False  False   True  False  False  False  False  False
# 41480   False  False   True  False  False  False  False  False
# 41490   False  False  False  False  False  False  False  False
# 41500   False  False   True  False  False  False  False  False
# 41510   False   True  False  False  False  False   True  False
# 41660   False  False  False  False  False  False  False  False
# 41670   False   True  False  False  False  False  False  False
# 41680   False  False  False  False  False   True  False  False
# 41690   False   True  False  False  False  False  False  False
#
#                            Location
# MAP_ID
# 40010       (41.870851, -87.776812)
# 40020       (41.886848, -87.803176)
# 40030       (41.885412, -87.725404)
# 40040        (41.878723, -87.63374)
# 40050        (42.04771, -87.683543)
# 40060       (41.938132, -87.712359)
# 40070       (41.878183, -87.629296)
# 40080       (41.953775, -87.654929)
# 40090       (41.966286, -87.678639)
# 40100       (42.008362, -87.665909)
# ...                             ...
# 41450       (41.896671, -87.628176)
# 41460       (41.954521, -87.674868)
# 41480       (41.966163, -87.688502)
# 41490       (41.874039, -87.627479)
# 41500       (41.961756, -87.675047)
# 41510       (41.885586, -87.652193)
# 41660       (41.884809, -87.627813)
# 41670       (41.884904, -87.716523)
# 41680   (42.02624348, -87.74722084)
# 41690       (41.853115, -87.626402)
#
# [144 rows x 13 columns]

# %%
# A little Error Checking!

# In theory the two numbers below should be the same
print len(station_data['Location'].unique())
print len(final_station_data['Location'].unique())

# But they are not the same! Which value is different?
for location in station_data['Location'].unique():
    if not(location in final_station_data['Location'].unique()):
        print location
        
#   (41.867368, -87.627402) Corresponds to Roosevelt, This Also has an address at (41.867405, -87.62659)
#   Note how close the two stations are... thinking its basically the same but has two turnstiles
#   relatively far apart
# Out:
# 145
# 144
# (41.867368, -87.627402)

# %%
# Extract the station Location at a Numpy Array of the Latitude and Longitude
station_locations = final_station_data['Location']
cta_stations_lat_long = np.array([(float(x[1:-1].split(',')[0]),float(x[1:-1].split(',')[1])) for x in station_locations])
# Extract the station id/map_id at a Numpy Array of the Latitude and Longitude
cta_stations_station_id = np.array(station_locations.index)

# %%
cta_stations_lat_long.shape, cta_stations_station_id.shape
# Out:
# ((144, 2), (144,))

# %%
final_station_data.columns
# Out:
# Index([u'STATION_NAME', u'STATION_DESCRIPTIVE_NAME', u'ADA', u'RED', u'BLUE',
#        u'G', u'BRN', u'P', u'Pexp', u'Y', u'Pnk', u'O', u'Location'],
#       dtype='object')

# %%
print "Total Number of Stations", len(final_station_data)
print "Red Line Stations", final_station_data.RED.value_counts()[1]
print "Blue Line Stations", final_station_data.BLUE.value_counts()[1]
print "Brown Line Stations", final_station_data.BRN.value_counts()[1]
print "Purple Line Stations", final_station_data.P.value_counts()[1]
print "Purple Express Line Stations", final_station_data.Pexp.value_counts()[1]
print "Green Line Stations", final_station_data.G.value_counts()[1]
print "Yellow Line Stations", final_station_data.Y.value_counts()[1]
print "Orange Line Stations", final_station_data.O.value_counts()[1]
print "Pink Line Stations", final_station_data.Pnk.value_counts()[1]
print "Number of ADA Compliant Stations", final_station_data.ADA.value_counts()[1]

# Note that I believe that all Purple Express Line Stations are also Purple Stations!
# Out:
# Total Number of Stations 144
# Red Line Stations 33
# Blue Line Stations 33
# Brown Line Stations 28
# Purple Line Stations 9
# Purple Express Line Stations 26
# Green Line Stations 31
# Yellow Line Stations 3
# Orange Line Stations 17
# Pink Line Stations 23
# Number of ADA Compliant Stations 97

# %%
# Assign Each Station Location a Color:
final_station_colors = []
station_colors = final_station_data[['RED', 'BLUE', 'G','BRN','P', 'Pexp','Y', 'Pnk', 'O']]
station_colors = np.array(station_colors)

# Verifying that all Purple Lines are Purple Express!  Treat as one
'''
for i,row in enumerate(station_colors):
    if row[4]:
        print i, row[5]
'''
station_colors = np.delete(station_colors,4,axis=1)
for i,row in enumerate(station_colors):
    if sum(row) > 1:
        final_station_colors.append('black')
    else:
        if row[0]:
            final_station_colors.append('red')
        elif row[1]:
            final_station_colors.append('blue')
        elif row[2]:
            final_station_colors.append('green')  
        elif row[3]:
            final_station_colors.append('brown')
        elif row[4]:
            final_station_colors.append('purple')
        elif row[5]:
            final_station_colors.append('yellow')
        elif row[6]:
            final_station_colors.append('pink')
        elif row[7]:
            final_station_colors.append('orange')
        else:
            "What color is this??"

final_station_colors = np.array(final_station_colors)

# %%
# Check that the arrays have the shape I think they should
len(final_station_colors), cta_stations_lat_long.shape
# Out:
# (144, (144, 2))

# %% [markdown]
# ## Plotting The Stations on a map based on the color of their line

# %%
#plt.hold(True)
for color in np.unique(final_station_colors):
    indices = final_station_colors==color
    plt.plot(cta_stations_lat_long[indices,1], cta_stations_lat_long[indices,0], 'o', 
         color = color, 
         alpha = 0.8)
    
mplleaflet.show(path='plot_cta_stations_on_map.html')
#mplleaflet.display()

# %% [markdown]
# ## See output at
# http://htmlpreview.github.io/?https://github.com/carolynlphillips/CTA_Ridership_Analysis/blob/master/plot_cta_stations_on_map.html

# %%
# WHEEEE, Now we can map trends!

# %%
print "Number of rows present in the Turnstile Data", len(turnstile_data)
print turnstile_data.columns
# Out:
# Number of rows present in the Turnstile Data 809326
# Index([u'station_id', u'stationname', u'date', u'daytype', u'rides'], dtype='object')

# %%
# How many different dates are present in the dataset?
print "Number of dates present", len(turnstile_data['date'].unique())
# Out:
# Number of dates present 5691

# %%
# How much data is available for each year?  (Note that below2016 has less data, just as one would expect)
for year in np.arange(2001,2017):
    print "Year:", year, "Number of data points", turnstile_data['date'].str.contains(str(year)).sum()
# Out:
# Year: 2001 Number of data points 51710
# Year: 2002 Number of data points 51830
# Year: 2003 Number of data points 51830
# Year: 2004 Number of data points 51972
# Year: 2005 Number of data points 51830
# Year: 2006 Number of data points 51830
# Year: 2007 Number of data points 51830
# Year: 2008 Number of data points 51972
# Year: 2009 Number of data points 51496
# Year: 2010 Number of data points 51465
# Year: 2011 Number of data points 52083
# Year: 2012 Number of data points 52126
# Year: 2013 Number of data points 51925
# Year: 2014 Number of data points 52195
# Year: 2015 Number of data points 52560
# Year: 2016 Number of data points 30672

# %%
turnstile_2016_data = turnstile_data[turnstile_data['date'].str.contains(str(2016))]

# %%
# Observation U = Sunday or Holiday, A = Saturday.  W = Weekdays, Not certain of this!

# %%
weekend_holiday = turnstile_2016_data['daytype'].str.contains('A') | turnstile_2016_data['daytype'].str.contains('U')
aggregated_rides = np.array(pd.DataFrame(turnstile_2016_data[weekend_holiday].groupby("station_id").sum())['rides'])
map_ids = np.array(pd.DataFrame(turnstile_2016_data[weekend_holiday].groupby("station_id").sum()).index)

# %%
min(aggregated_rides), max(aggregated_rides)
# Out:
# (154, 744484)

# %%
print "Ranked Stations by Weekend/Holiday Ridership"

for i, (station_name, net_weekend_ridership) in enumerate(sorted(zip([final_station_data[final_station_data.index==mid]['STATION_DESCRIPTIVE_NAME'].values[0] for mid in map_ids],
# 140 Oakton-Skokie (Yellow Line) : 23695
# 141 Halsted (Green Line) : 23308
# 142 Kostner (Pink Line) : 17500
# 143 Madison/Wabash (Brown, Green, Orange, Pink & Purple Lines) : 154

# %%
# WHAT STOPS ARE POPULAR ON WEEKENDS AND HOLIDAYS!   Making Stop Size Proportional to Ridership

# This scales the size of the dots
ms_scale = 50000.
for station_id,lat_lng,color in zip(cta_stations_station_id,cta_stations_lat_long,final_station_colors):
    ind = np.where(map_ids==station_id)[0][0]
    agg_rides = aggregated_rides[ind]
    
    plt.plot(lat_lng[1], lat_lng[0], 'o', 
         color = color, ms = agg_rides/ms_scale,
         alpha = 0.5)
    
mplleaflet.show(path='plot_cta_stations_weekends_2016.html')
#mplleaflet.display()

# %% [markdown]
# ## See Output at
# http://htmlpreview.github.io/?https://github.com/carolynlphillips/CTA_Ridership_Analysis/blob/master/plot_cta_stations_weekends_2016.html

# %%
weekday = turnstile_2016_data['daytype'].str.contains('W') 
aggregated_rides = np.array(pd.DataFrame(turnstile_2016_data[weekday].groupby("station_id").sum())['rides'])
map_ids = np.array(pd.DataFrame(turnstile_2016_data[weekday].groupby("station_id").sum()).index)

# %%
print "Ranked Stations by Weekday Ridership"
for i, (station_name, net_weekday_ridership) in enumerate(sorted(zip([final_station_data[final_station_data.index==mid]['STATION_DESCRIPTIVE_NAME'].values[0] for mid in map_ids],
                                                                aggregated_rides),key = lambda x: x[1], reverse = True)):
    print i, station_name, ":", net_weekday_ridership
# Out:
# Ranked Stations by Weekday Ridership
# 0 Lake (Red Line) : 3279652
# 1 Clark/Lake (Blue, Brown, Green, Orange, Purple & Pink Lines) : 3093500
# 2 Chicago (Red Line) : 2284224
# 3 Fullerton (Red, Brown & Purple Lines) : 1970957
# 4 Belmont (Red, Brown & Purple Lines) : 1896210
# 5 Washington (Blue Line) : 1819789
# 6 Grand (Red Line) : 1809420
# 7 Monroe (Red Line) : 1722115
# 8 Jackson (Red Line) : 1693239
# 9 O'Hare (Blue Line) : 1655853
# 10 Roosevelt (Red, Orange & Green Lines) : 1655090
# 11 95th/Dan Ryan (Red Line) : 1630959
# 12 State/Lake (Brown, Green, Orange, Pink & Purple Lines) : 1486540
# 13 Randolph/Wabash (Brown, Green, Orange, Pink & Purple Lines) : 1466559
# 14 Adams/Wabash (Brown, Green, Orange, Pink & Purple Lines) : 1397263
# 15 Midway (Orange Line) : 1320619
# 16 Addison (Red Line) : 1278645
# 17 Washington/Wells (Brown, Orange, Purple & Pink Lines) : 1234528
# 18 Quincy/Wells (Brown, Orange, Purple & Pink Lines) : 1213606
# 19 Clark/Division (Red Line) : 1210776
# 20 Monroe (Blue Line) : 1187633
# 21 Merchandise Mart (Brown & Purple Lines) : 1186904
# 22 Jackson (Blue Line) : 1170553
# 23 Logan Square (Blue Line) : 1090991
# 24 79th (Red Line) : 1072659
# 25 Jefferson Park (Blue Line) : 1043707
# 26 Chicago (Brown & Purple Lines) : 1026182
# 27 Damen (Blue Line) : 1020730
# 28 North/Clybourn (Red Line) : 941513
# 29 Rosemont (Blue Line) : 940356
# 30 Division (Blue Line) : 937607
# 31 Wilson (Red Line) : 872984
# 105 Ashland (Orange Line) : 244517
# 106 Kedzie (Green Line) : 243481
# 107 Francisco (Brown Line) : 238991
# 108 Oak Park (Green Line) : 235494
# 109 California (Pink Line) : 226992
# 110 Damen (Pink Line) : 224493
# 111 Pulaski (Green Line) : 222383
# 112 Cicero (Blue Line) : 213147
# 113 Garfield (Green Line) : 205379
# 114 Cicero (Green Line) : 204329
# 115 Ridgeland (Green Line) : 198550
# 116 Cermak-McCormick Place (Green Line) : 194765
# 117 Cicero (Pink Line) : 190156
# 118 Laramie (Green Line) : 186956
# 119 47th (Green Line) : 186508
# 120 Central Park (Pink Line) : 181632
# 121 Harlem (Blue Line - Forest Park Branch) : 177683
# 122 Ashland/63rd (Green Line) : 177290
# 123 Main (Purple Line) : 175120
# 124 Cottage Grove (Green Line) : 173752
# 125 Western (Pink Line) : 172394
# 126 Pulaski (Pink Line) : 171762
# 127 California (Green Line) : 163295
# 128 Kedzie (Pink Line) : 160933
# 129 43rd (Green Line) : 157793
# 130 51st (Green Line) : 154159
# 131 Linden (Purple Line) : 141173
# 132 Conservatory (Green Line) : 140677
# 133 Foster (Purple Line) : 139823
# 134 Noyes (Purple Line) : 132418
# 135 Indiana (Green Line) : 128928
# 136 Oakton-Skokie (Yellow Line) : 127971
# 137 Dempster (Purple Line) : 125739
# 138 Central (Purple Line) : 119895
# 139 South Boulevard (Purple Line) : 118310
# 140 Halsted (Green Line) : 100880
# 141 King Drive (Green Line) : 89517
# 142 Kostner (Pink Line) : 77248
# 143 Madison/Wabash (Brown, Green, Orange, Pink & Purple Lines) : 0

# %%
# WHAT STOPS ARE POPULAR ON WEEKDAYS!   Making Stop Size Proportional to Ridership

ms_scale = 50000.
for station_id,lat_lng,color in zip(cta_stations_station_id,cta_stations_lat_long,final_station_colors):
    ind = np.where(map_ids==station_id)[0][0]
    agg_rides = aggregated_rides[ind]
    
    plt.plot(lat_lng[1], lat_lng[0], 'o', 
         color = color, ms = agg_rides/ms_scale,
         alpha = 0.5)
    
mplleaflet.show(path='plot_cta_stations_weekdays_2016.html')
#mplleaflet.display()

# %% [markdown]
# ## See Output at
# http://htmlpreview.github.io/?https://github.com/carolynlphillips/CTA_Ridership_Analysis/blob/master/plot_cta_stations_weekdays_2016.html

# %%
# NEXT IT WOULD BE FUN TO USE GEOPANDAS TO USE POLYGONS DEFINED 
# OVER THE CITY OF CHICAGO AND THEN COLOR THOSE POLYGONS 
# BASED ON A MEASURE OF THE PROJECTED INCIDENTAL FOOT TRAFFIC IN THAT POLYGON

# %%
# Let's look at some general trends of ridership on the CTA

# %%
years = np.arange(2001,2017,1)
turnstile_year_data = []
for i,year in enumerate(years):
    turnstile_year_data.append(turnstile_data[turnstile_data['date'].str.contains(str(year))])

# %%
turnstile_2016_data[weekday]['rides'].sum()
# Out:
# 92188240

# %%
agg_rides_per_year_weekday = []
for i in range(len(years)):
    weekday = turnstile_year_data[i]['daytype'].str.contains('W')
    agg_rides_per_year_weekday.append(turnstile_year_data[i][weekday]['rides'].sum())

# %%
agg_rides_per_year_weekday_by_station = {}
for i in range(len(years)):
    weekday = turnstile_year_data[i]['daytype'].str.contains('W')
    aggregated_rides = np.array(pd.DataFrame(turnstile_year_data[i][weekday].groupby("station_id").sum())['rides'])
    map_ids = np.array(pd.DataFrame(turnstile_year_data[i][weekday].groupby("station_id").sum()).index)
    
    for j,mid in enumerate(map_ids):
        pair = np.array((years[i],aggregated_rides[j]))
        if agg_rides_per_year_weekday_by_station.has_key(mid):
            agg_rides_per_year_weekday_by_station[mid].append(pair)
        else:
            agg_rides_per_year_weekday_by_station[mid] = [pair]

# %%
agg_rides_per_year_weekend = []
for i in range(len(years)):
    weekend = turnstile_year_data[i]['daytype'].str.contains('A') | turnstile_year_data[i]['daytype'].str.contains('U')

    agg_rides_per_year_weekend.append(turnstile_year_data[i][weekend]['rides'].sum())

# %%
agg_rides_per_year_weekend_by_station = {}
for i in range(len(years)):
    weekend = turnstile_year_data[i]['daytype'].str.contains('A') | turnstile_year_data[i]['daytype'].str.contains('U')
    aggregated_rides = np.array(pd.DataFrame(turnstile_year_data[i][weekend].groupby("station_id").sum())['rides'])
    map_ids = np.array(pd.DataFrame(turnstile_year_data[i][weekend].groupby("station_id").sum()).index)
    
    for j,mid in enumerate(map_ids):
        pair = np.array((years[i],aggregated_rides[j]))
        if agg_rides_per_year_weekend_by_station.has_key(mid):
            agg_rides_per_year_weekend_by_station[mid].append(pair)
        else:
            agg_rides_per_year_weekend_by_station[mid] = [pair]

# %%
# %matplotlib inline
plt.plot(years[:-1],agg_rides_per_year_weekday[:-1], lw = 5, label = 'Net weekday usage')
plt.plot(years[:-1],agg_rides_per_year_weekend[:-1], lw = 5, label = 'Net weekend usage')

plt.title('Net Ridership of CTA over last 15 years')
plt.xlabel('years')
plt.ylim([0,2e8])
plt.ylabel('100s of millions of rides')
plt.legend(loc = 'upper left')

# %%
fig = plt.figure(figsize = (10,10))
for sid in final_station_data.index:
    data = np.array(agg_rides_per_year_weekday_by_station[sid])
    plt.plot(data[:-1,0], data[:-1,1])
plt.title('Net Ridership of CTA over for Each Station on Weekdays for last 15 years')
plt.xlabel('years')
plt.ylabel('number of rides')
plt.legend(loc = 'upper left')

# %%
fig = plt.figure(figsize = (10,10))
for sid in final_station_data.index:
    data = np.array(agg_rides_per_year_weekend_by_station[sid])
    plt.plot(data[:-1,0], data[:-1,1])
plt.title('Net Ridership of CTA over for Each Station on Weekends for last 15 years')
plt.xlabel('years')
plt.ylabel('number of rides')
plt.legend(loc = 'upper left')

# %% [raw]
# from mpl_toolkits.basemap import Basemap
#
# # EARLIER EXPERIMENTATIONS WITH MAPPINGS!
#
#
# fig = plt.figure(figsize =(10,10))
#
# # 41.8781° N, 87.6298° W
# clat = 41.8781
# clong =87.6298
# width = 0.3
# m = Basemap(llcrnrlon=-clong-width,llcrnrlat=clat-width,urcrnrlon=-clong+width,urcrnrlat=clat+width,
#                 projection='merc',resolution='h')
# # draw coastlines.
# m.drawcoastlines()
# m.drawstates()
#
# # draw a boundary around the map, fill the background.
# # this background will end up being the ocean color, since
# # the continents will be drawn on top.
# m.drawmapboundary(fill_color='white')
#
#
#
# x1, y1 = m(cta_stations_lat_long[:,1],cta_stations_lat_long[:,0])
# m.scatter(x1,y1,marker="o",alpha=0.5)
